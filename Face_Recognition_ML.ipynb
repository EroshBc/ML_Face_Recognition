# %% [markdown]
# Face recognition using ML SVM mode

# %%
import os
import numpy as np
import cv2
import sys

data_path= "TrainData"

# %%
# Get all non-hidden files and folders to list
categories1 = [item for item in os.listdir(data_path) if not item.startswith('.')]


labels1 = [i for i in range(len(categories1))] #make lables 

#assign labels to each category
categories_dict1 = {'Barack Obama':0, 'Donald Trump':1, 'George W Bush':2}

# %%
print(categories1)
print(labels1)
print (categories_dict1)
# Out:
# ['Barack Obama', 'Donald Trump', 'George W Bush']
# [0, 1, 2]
# {'Barack Obama': 0, 'Donald Trump': 1, 'George W Bush': 2}

# %% [markdown]
# ### Create data set another method

# %%
labels = [i for i in os.listdir(data_path)
         if not i.startswith('.') and os.path.isdir(os.path.join(data_path,i))]

# %%
print (labels)
# Out:
# ['Barack Obama', 'Donald Trump', 'George W Bush']

# %%
categories = np.arange(len(labels))
print(categories)
# Out:
# [0 1 2]

# %%
# attached categories to labels

categories_dict = dict(zip(labels,categories))
print(categories_dict)
# Out:
# {'Barack Obama': 0, 'Donald Trump': 1, 'George W Bush': 2}

# %%
for label in labels:
    imgs_path = os.path.join(data_path, label) ## add image data path to labels
    print(label)
# Out:
# Barack Obama
# Donald Trump
# George W Bush
